# %%
from src.datasets.drive_dataset import DriveDataset, DriveDatasetArgs
from src.args.yaml_config import YamlConfig
import cv2
import numpy as np
import matplotlib.pyplot as plt
import torch
yaml_config = YamlConfig()
config = DriveDatasetArgs()
ds = DriveDataset(config, yaml_config.config).get_split('test')
sample = ds[1]

image = sample.input.permute(1,2,0).cpu().numpy()


plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.12486065..1.1763922].
# tensor(94.7179) tensor(70.9390)
